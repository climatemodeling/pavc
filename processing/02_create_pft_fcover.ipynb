# %%
import pandas as pd
import geopandas as gpd
import re
import os
from osgeo import gdal
import geopandas as gpd
import rasterio
import sys
import importlib
import re
import pandas as pd
import csv
import numpy as np
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from rasterio.transform import from_bounds
from rasterio.features import rasterize
from pathlib import Path
import json

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# find helper scripts
project_root = Path.cwd().parent

# 2) Add that root to sys.path
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
import pavc_funcs.standardize_pft_funcs as spf
importlib.reload(spf)
# Out:
# <module 'pavc_funcs.standardize_pft_funcs' from '/mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py'>

# %% [markdown]
# ---
# # Helper functions

# %%
# rename columns for ESS-Dive
def camel_to_snake(name):
    name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub('([a-z0-9])([A-Z])', r'\1_\2', name)
    return name.lower()

# throughout the script this will help keep my indices matching
def normalize_to_int_str(val):
    try:
        f = float(val)
        i = int(f)
        if f == i:
            return str(i)
    except (ValueError, TypeError):
        # now also catches the int(inf) case
        pass
    return str(val)

# %% [markdown]
# ---
# # 1. Create `synthesized_pft_fcover.csv`

# %%
# load aux data
aux = pd.read_csv('../pavc/survey_unit_information.csv', index_col=0)
aux
# Out:
#             survey_year  survey_month  survey_day    plot_area plot_shape  \
# visit_id
# u580f8d998         2012             7        15.0  9503.317777     circle
# u7237c5455         2012             8        15.0  9503.317777     circle
# u5a8ac1d8b         2012             7        27.0  9503.317777     circle
# u59bc4b4ea         2012             8         6.0  9503.317777     circle
# u28d3422f0         2012             8         6.0  9503.317777     circle
# ...                 ...           ...         ...          ...        ...
# ubed4eb698         2016             7        19.0     4.908739     circle
# u8c1017982         2016             7        19.0     4.908739     circle
# u07dcd3715         2016             7        18.0     4.908739     circle
# u6d3236ec3         2016             7        19.0     4.908739     circle
# ueffdb5f96         2016             7        18.0     4.908739     circle
#
#             latitude_y  longitude_x georef_source  georef_accuracy coord_epsg  \
# visit_id
# u580f8d998   69.256149  -152.240143           GPS             3.00  EPSG:4326
# u7237c5455   69.289886  -152.499603           GPS             3.00  EPSG:4326
# u5a8ac1d8b   69.297775  -152.493607           GPS             3.00  EPSG:4326
# u59bc4b4ea   69.340195  -152.217621           GPS             3.00  EPSG:4326
# u28d3422f0   69.343254  -152.214981           GPS             3.00  EPSG:4326
# ...                ...          ...           ...              ...        ...
# ubed4eb698   65.165445  -164.821015           GPS             0.25  EPSG:4326
# u8c1017982   65.166040  -164.818240           GPS             0.25  EPSG:4326
# u07dcd3715   65.166275  -164.818973           GPS             0.25  EPSG:4326
# u6d3236ec3   65.166678  -164.815835           GPS             0.25  EPSG:4326
# ueffdb5f96   65.167195  -164.816835           GPS             0.25  EPSG:4326
#
#             ... fcover_scale  \
# visit_id    ...
# u580f8d998  ...      percent
# u7237c5455  ...      percent
# u5a8ac1d8b  ...      percent
# u59bc4b4ea  ...      percent
# u28d3422f0  ...      percent
# ...         ...          ...
# ubed4eb698  ...      percent
# u8c1017982  ...      percent
# u07dcd3715  ...      percent
# u6d3236ec3  ...      percent
# ueffdb5f96  ...      percent
#
#                                                survey_purpose admin_unit  \
# visit_id
# u580f8d998  Conduct vegetation assessments and paired remo...     Alaska
# u7237c5455  Conduct vegetation assessments and paired remo...     Alaska
# u5a8ac1d8b  Conduct vegetation assessments and paired remo...     Alaska
# u59bc4b4ea  Conduct vegetation assessments and paired remo...     Alaska
# u28d3422f0  Conduct vegetation assessments and paired remo...     Alaska
# ...                                                       ...        ...
# ubed4eb698  Improve predictability of carbon-rich Arctic s...     Alaska
# u8c1017982  Improve predictability of carbon-rich Arctic s...     Alaska
# u07dcd3715  Improve predictability of carbon-rich Arctic s...     Alaska
# u6d3236ec3  Improve predictability of carbon-rich Arctic s...     Alaska
# ueffdb5f96  Improve predictability of carbon-rich Arctic s...     Alaska
#
#                        admin_country fire_years bioclim_subzone  \
# visit_id
# u580f8d998  United States of America         []               E
# u7237c5455  United States of America         []               E
# u5a8ac1d8b  United States of America         []               E
# u59bc4b4ea  United States of America         []               E
# u28d3422f0  United States of America         []               E
# ...                              ...        ...             ...
# ubed4eb698  United States of America         []               E
# u8c1017982  United States of America         []               E
# u07dcd3715  United States of America         []               E
# u6d3236ec3  United States of America         []               E
# ueffdb5f96  United States of America         []               E
#
#            duplicated_coords  \
# visit_id
# u580f8d998                []
# u7237c5455                []
# u5a8ac1d8b                []
# u59bc4b4ea                []
# u28d3422f0                []
# ...                      ...
# ubed4eb698                []
# u8c1017982                []
# u07dcd3715                []
# u6d3236ec3                []
# ueffdb5f96                []
#
#                                              duplicated_date cavm_unit  \
# visit_id
# u580f8d998                                                []        G4
# u7237c5455                          ['120815a1', '120815b1']        G4
# u5a8ac1d8b              ['120727a1', '120727a2', '120727b1']        G4
# u59bc4b4ea  ['120806a1', '120806a2', '120806b1', '120806b2']        G4
# u28d3422f0  ['120806a1', '120806a2', '120806b1', '120806b2']        G4
# ...                                                      ...       ...
# ubed4eb698                    ['pp', 'qq', 'rr', 'ss', 'tt']        G4
# u8c1017982                    ['pp', 'qq', 'rr', 'ss', 'tt']        W3
# u07dcd3715               ['eee', 'fff', 'ggg', 'hhh', 'iii']        G4
# u6d3236ec3                    ['pp', 'qq', 'rr', 'ss', 'tt']        W3
# ueffdb5f96               ['eee', 'fff', 'ggg', 'hhh', 'iii']        W3
#
#                               cavm_unit_description
# visit_id
# u580f8d998  Tussock-sedge, dwarf-shrub, moss tundra
# u7237c5455  Tussock-sedge, dwarf-shrub, moss tundra
# u5a8ac1d8b  Tussock-sedge, dwarf-shrub, moss tundra
# u59bc4b4ea  Tussock-sedge, dwarf-shrub, moss tundra
# u28d3422f0  Tussock-sedge, dwarf-shrub, moss tundra
# ...                                             ...
# ubed4eb698  Tussock-sedge, dwarf-shrub, moss tundra
# u8c1017982   Sedge, moss, low-shrub wetland complex
# u07dcd3715  Tussock-sedge, dwarf-shrub, moss tundra
# u6d3236ec3   Sedge, moss, low-shrub wetland complex
# ueffdb5f96   Sedge, moss, low-shrub wetland complex
#
# [976 rows x 26 columns]

# %%
# pft_fcover
sources = ['abr', 'akveg', 'ava', 'neon', 'nga']
pft_dfs = []
all_num_visits = []
for src in sources:
    df = pd.read_csv(f'../data/plot_data/{src}/output_data/{src}_standard_pft_fcover.csv',
                     index_col=0, encoding='utf-8-sig')
    df.columns = [camel_to_snake(c) for c in df.columns]
    df.index.name = 'visit_id'
    pft_dfs.append(df)
    all_num_visits.append(len(df.index))
print(f'Table-wise visits: {sum(all_num_visits)}')

# adjust column names and index
pft_fcover = pd.concat(pft_dfs)
print(f'PFT-fcover table visits: {len(pft_fcover)}')

# subselect pft_fcover data collected before 2010
subset_pft_fcover = pft_fcover.loc[aux.index]
print(f'PFT-fcover table visits on or after 2010: {len(subset_pft_fcover)}')
# Out:
# Table-wise visits: 3246
# PFT-fcover table visits: 3246
# PFT-fcover table visits on or after 2010: 976

# %%
# ensure the data are formatted correctly and makes sense
pft_fcover_df = spf.validate_synthesized_pft_fcover(subset_pft_fcover)
pft_fcover_df.set_index('visit_id', drop=True, inplace=True)
# Out:
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u24e5f72e6' has total cover 100.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u7d8263433' has total cover 81.6 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u80356564d' has total cover 49.3 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ubf1204749' has total cover 81.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u9ce2eede1' has total cover 91.8 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ua744b2034' has total cover 81.9 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ua08ccabde' has total cover 63.4 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u236ba8f9a' has total cover 95.4 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u8d260182c' has total cover 94.2 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u81a4dcd1c' has total cover 39.5 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='uc1c1670fb' has total cover 78.6 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u4cd2b8a20' has total cover 28.7 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ud085579a0' has total cover 90.9 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ucb3261f6d' has total cover 81.9 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u3c98169d8' has total cover 64.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ua00a0727e' has total cover 28.5 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u05ead44ad' has total cover 89.8 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u87c9dfdbc' has total cover 70.8 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u9d925b9a7' has total cover 86.7 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u3a1fdf687' has total cover 99.2 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u5689e20b8' has total cover 76.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='uca447141f' has total cover 91.1 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='uf04b50754' has total cover 76.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ubd7b901c5' has total cover 74.4 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ucb8eeee1f' has total cover 96.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u7be9196d8' has total cover 92.5 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='uab94ee517' has total cover 98.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ubf9661def' has total cover 0.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='u857817355' has total cover 0.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)
# /mnt/poseidon/remotesensing/arctic/alaska_pft_fcover_harmonization/pavc_funcs/standardize_pft_funcs.py:273: UserWarning: visit_id='ua056c8d05' has total cover 0.0 < 100
#   warnings.warn(f"visit_id={vid!r} has total cover {tot:.1f} < 100", UserWarning)

# %% [markdown]
# ## Create `synthesized_pft_fcover_dd.csv`

# %%
# UNITS_AND_DEFS = { col: {"unit": "", "definition": ""} for col in pft_fcover_df.columns }
# print(json.dumps(UNITS_AND_DEFS, indent=4))

# %%
dd_info = {
    "visit_id": {
        "unit": 1,
        "definition": "A unique identifier representing the survey unit visitation at a particular survey unit; some survey units are visited more than once"
    },
    "deciduous_shrub_cover": {
        "unit": "percent",
        "definition": "Percent total cover of deciduous shrubs"
    },
    "deciduous_tree_cover": {
        "unit": "percent",
        "definition": "Percent total cover of deciduous trees"
    },
    "evergreen_shrub_cover": {
        "unit": "percent",
        "definition": "Percent total cover of evergreen shrubs"
    },
    "evergreen_tree_cover": {
        "unit": "percent",
        "definition": "Percent total cover of evergreen trees"
    },
    "forb_cover": {
        "unit": "percent",
        "definition": "Percent total cover of forbs (herbaceous plants and spore-bearing plants)"
    },
    "graminoid_cover": {
        "unit": "percent",
        "definition": "Percent total cover of graminoids (grasses, sedges)"
    },
    "nonvascular_sum_cover": {
        "unit": "percent",
        "definition": "Percent total cover of bryophytes and lichens summed"
    },
    "bryophyte_cover": {
        "unit": "percent",
        "definition": "Percent total cover of bryophytes (mosses and liverworts)"
    },
    "lichen_cover": {
        "unit": "percent",
        "definition": "Percent total cover of lichens"
    },
    "litter_cover": {
        "unit": "percent",
        "definition": "Percent total cover of litter (includes scat; varying litter definitions; not all studies collected litter information)"
    },
    "bareground_cover": {
        "unit": "percent",
        "definition": "Percent top cover of bare ground (sum of rock, pebbles, crust, bare soil, etc.)"
    },
    "water_cover": {
        "unit": "percent",
        "definition": "Percent top cover of water (assumption made for AVA quadrat plots; studies did not always specify if they collected top or total water cover)"
    },
    "other_cover": {
        "unit": "percent",
        "definition": "Percent total cover of other vegetation types summed together (fungus, cyanobacteria, algae, standing dead vegetation, unknown vegetation, etc.)"
    }
}

# %%
import pandas as pd
import typing
from typing import get_origin, get_args

from pavc_funcs.schemas import SCHEMAS
SynthesizedAux = SCHEMAS["synthesized_pft_fcover"]

dtype_map = {}
for name, field in SynthesizedAux.model_fields.items():
    t      = field.annotation
    origin = get_origin(t)
    args   = get_args(t)

    # 1) Explicit primitives
    if t is str:
        pd_type = "string"
    elif t is float:
        pd_type = "float64"
    elif t is int:
        pd_type = "Int64"            # nullable int

    # 2) Optionals
    elif origin is typing.Union and set(args) == {int, type(None)}:
        pd_type = "Int64"
    elif origin is typing.Union and set(args) == {str, type(None)}:
        pd_type = "string"
    elif origin is typing.Union and set(args) == {float, type(None)}:
        pd_type = "float64"

    # 3) Lists stay object
    elif origin in (list, typing.List):
        pd_type = "object"

    # 4) Everything else → string
    else:
        pd_type = "string"

    dtype_map[name] = pd_type

# cast in one go
pft_fcover_df.reset_index(inplace=True)
pft_fcover_df = pft_fcover_df.astype(dtype_map)

# build your DD exactly as before
rows = []
for col in pft_fcover_df.columns:
    meta = dd_info.get(col, {"unit": "", "definition": ""})
    rows.append({
        "column_name":      col,
        "unit":             meta["unit"],
        "definition":       meta["definition"],
        "column_long_name": col,
        "data_type":        pft_fcover_df[col].dtype.name
    })

dd_df = pd.DataFrame(rows, columns=[
    "column_name","unit","definition","column_long_name","data_type"
])

# %%
dd_df
# Out:
#               column_name     unit  \
# 0                visit_id        1
# 1   deciduous_shrub_cover  percent
# 2    deciduous_tree_cover  percent
# 3   evergreen_shrub_cover  percent
# 4    evergreen_tree_cover  percent
# 5              forb_cover  percent
# 6         graminoid_cover  percent
# 7   nonvascular_sum_cover  percent
# 8         bryophyte_cover  percent
# 9            lichen_cover  percent
# 10           litter_cover  percent
# 11       bareground_cover  percent
# 12            water_cover  percent
# 13            other_cover  percent
#
#                                            definition       column_long_name  \
# 0   A unique identifier representing the survey un...               visit_id
# 1             Percent total cover of deciduous shrubs  deciduous_shrub_cover
# 2              Percent total cover of deciduous trees   deciduous_tree_cover
# 3             Percent total cover of evergreen shrubs  evergreen_shrub_cover
# 4              Percent total cover of evergreen trees   evergreen_tree_cover
# 5   Percent total cover of forbs (herbaceous plant...             forb_cover
# 6   Percent total cover of graminoids (grasses, se...        graminoid_cover
# 7   Percent total cover of bryophytes and lichens ...  nonvascular_sum_cover
# 8   Percent total cover of bryophytes (mosses and ...        bryophyte_cover
# 9                      Percent total cover of lichens           lichen_cover
# 10  Percent total cover of litter (includes scat; ...           litter_cover
# 11  Percent top cover of bare ground (sum of rock,...       bareground_cover
# 12  Percent top cover of water (assumption made fo...            water_cover
# 13  Percent total cover of other vegetation types ...            other_cover
#
#    data_type
# 0     string
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# 7    float64
# 8    float64
# 9    float64
# 10   float64
# 11   float64
# 12   float64
# 13   float64

# %%
pft_fcover_df.head(3)
# Out:
#      visit_id  deciduous_shrub_cover  deciduous_tree_cover  \
# 0  u580f8d998              17.440001                   NaN
# 1  u7237c5455              47.720001                   NaN
# 2  u5a8ac1d8b              40.660000                   NaN
#
#    evergreen_shrub_cover  evergreen_tree_cover  forb_cover  graminoid_cover  \
# 0                  24.83                   NaN    9.390000        14.770000
# 1                    NaN                   NaN   40.279999        56.049999
# 2                    NaN                   NaN   21.340000        20.010000
#
#    nonvascular_sum_cover  bryophyte_cover  lichen_cover  litter_cover  \
# 0                  28.83        22.120001          6.71     75.169998
# 1                  39.68        39.680000           NaN     79.370003
# 2                  24.67        24.670000           NaN     79.330002
#
#    bareground_cover  water_cover  other_cover
# 0              0.67         3.36          NaN
# 1              1.59         0.00          NaN
# 2              6.00         0.00          NaN

# %%
# export pft_fcover
pft_fcover_df = pft_fcover_df.replace({None: np.nan, '':np.nan})
pft_fcover_df.to_csv('../pavc/synthesized_pft_fcover.csv', encoding='utf-8-sig', quoting=csv.QUOTE_ALL, index=False)

# %%
dd_df.to_csv('../pavc/synthesized_pft_fcover_dd.csv', encoding='utf-8-sig', quoting=csv.QUOTE_ALL, index=False)

# %% [markdown]
# ## Address all the pydantic warnings

# %%
# address coverage less than 100%
temp = pft_fcover_df.merge(aux, how='left', left_index=True, right_index=True)

# columns to exclude in summing
exclude = {'nonvascular_sum_cover'}

# identify *_cover cols, minus nonvascular_sum_cover
cover_cols = [
    c for c in df.columns
    if c.endswith('_cover') and c not in exclude
]

# get rows less summing than 100
row_sums = df[cover_cols].sum(axis=1)
mask = row_sums < 100
df_under100 = (
    df
    .loc[mask]            # all columns, only rows where sum<100
    .copy()               # avoid SettingWithCopyWarning
    .assign(total_sum=row_sums[mask])
)

# %%
# determine the culprit of data summing to <100
df_under100.merge(aux[['data_source', 'data_subsource']], 
                  how='left', left_index=True, right_index=True)
# Out:
#             deciduous_shrub_cover  deciduous_tree_cover  \
# visit_id
# u3c363836c                   26.0                   NaN
# ue9d71f5ee                   29.0                   NaN
# u1c4f0c6eb                   16.0                   NaN
# u7e240de74                    0.0                   NaN
# ud7dacae2c                    5.0                   NaN
# u6f457e97a                   13.0                   NaN
# ubf9661def                    0.0                   NaN
# u857817355                    0.0                   NaN
# ua056c8d05                    0.0                   NaN
# u782337220                    1.0                   NaN
#
#             evergreen_shrub_cover  evergreen_tree_cover  forb_cover  \
# visit_id
# u3c363836c                   41.0                   NaN         6.0
# ue9d71f5ee                   47.0                   NaN         2.0
# u1c4f0c6eb                   28.0                   NaN         1.0
# u7e240de74                   65.0                   NaN         4.0
# ud7dacae2c                   57.0                   NaN         2.0
# u6f457e97a                   30.0                   NaN         1.0
# ubf9661def                    0.0                   0.0         0.0
# u857817355                    0.0                   0.0         0.0
# ua056c8d05                    0.0                   0.0         0.0
# u782337220                    6.0                   0.0         2.0
#
#             graminoid_cover  nonvascular_sum_cover  bryophyte_cover  \
# visit_id
# u3c363836c             11.0                   13.0             13.0
# ue9d71f5ee             14.0                    6.0              6.0
# u1c4f0c6eb              4.0                   37.0              3.0
# u7e240de74              0.0                   29.0              2.0
# ud7dacae2c              2.5                   19.5              0.0
# u6f457e97a              4.0                   31.5              1.5
# ubf9661def              0.0                    0.0              0.0
# u857817355              0.0                    0.0              0.0
# ua056c8d05              0.0                    0.0              0.0
# u782337220             31.0                   30.0             28.0
#
#             lichen_cover  litter_cover  bareground_cover  water_cover  \
# visit_id
# u3c363836c           NaN           0.0               0.0          0.0
# ue9d71f5ee           NaN           0.0               0.0          0.0
# u1c4f0c6eb          34.0           0.0               5.0          0.0
# u7e240de74          27.0           0.0               0.0          0.0
# ud7dacae2c          19.5           0.0               0.0          0.0
# u6f457e97a          30.0           0.0               3.0          0.0
# ubf9661def           0.0           0.0               0.0          0.0
# u857817355           0.0           0.0               0.0          0.0
# ua056c8d05           0.0           0.0               0.0          0.0
# u782337220           2.0           8.0               0.0          0.0
#
#             other_cover  total_sum data_source  \
# visit_id
# u3c363836c          NaN       97.0         NGA
# ue9d71f5ee          NaN       98.0         NGA
# u1c4f0c6eb          NaN       91.0         NGA
# u7e240de74          NaN       98.0         NGA
# ud7dacae2c          NaN       86.0         NGA
# u6f457e97a          NaN       82.5         NGA
# ubf9661def          NaN        0.0         NGA
# u857817355          NaN        0.0         NGA
# ua056c8d05          NaN        0.0         NGA
# u782337220          NaN       78.0         NGA
#
#                               data_subsource
# visit_id
# u3c363836c  NGEE-Arctic Amy Breen (pub 2020)
# ue9d71f5ee  NGEE-Arctic Amy Breen (pub 2020)
# u1c4f0c6eb  NGEE-Arctic Amy Breen (pub 2020)
# u7e240de74  NGEE-Arctic Amy Breen (pub 2020)
# ud7dacae2c  NGEE-Arctic Amy Breen (pub 2020)
# u6f457e97a  NGEE-Arctic Amy Breen (pub 2020)
# ubf9661def  NGEE-Arctic Amy Breen (pub 2020)
# u857817355  NGEE-Arctic Amy Breen (pub 2020)
# ua056c8d05  NGEE-Arctic Amy Breen (pub 2020)
# u782337220  NGEE-Arctic Amy Breen (pub 2020)
